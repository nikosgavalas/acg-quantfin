# %% [markdown]
# # Analysis

# %% [markdown]
# ## Initialization

# %%
# Imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

from statsmodels.tsa.api import VAR
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.stattools import adfuller, arma_order_select_ic
from statsmodels.tools.eval_measures import rmse, meanabs, mse

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.preprocessing.sequence import TimeseriesGenerator

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
# Utilities

def print_cols(data, padding=1):
    max_l = max(len(str(el)) for row in data for el in row)
    for row in data:
        print((f'{{:<{padding + max_l}}}' * len(row)).format(*row))


def logret(frame):
    return (np.log(frame) - np.log(frame).shift(1)).dropna()


def revlogret(frame, init_term):
    return np.exp(frame.cumsum() + np.log(init_term))


def evals(testframe, predframe, tickers):
    cols = [
        ['Stock', 'RMSE', 'MAE', 'MSE'],
        ['------------------'] * 4,
    ]

    for ticker in tickers:
        cols.append([
            ticker,
            rmse(testframe[ticker], predframe[ticker]),
            meanabs(testframe[ticker], predframe[ticker]),
            mse(testframe[ticker], predframe[ticker])
        ])
    
    print_cols(cols)

# %%
TICKERS = [
    'AAPL',  # Apple
    'AMZN',  # Amazon
    'GM',    # General Motors
    'JNJ',   # Johnson & Johnson
    'XOM',   # ExxonMobil
]

FIGSIZE = (13, 8)

# %% [markdown]
# ## Load Data and Visualize

# %%
df = pd.read_csv(f'data/{TICKERS[0]}.csv', index_col='Date', parse_dates=['Date'])
df.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
df.rename(columns={'Close': 'AAPL'}, inplace=True)

for ticker in TICKERS:
    tmddf = pd.read_csv(f'data/{ticker}.csv', index_col='Date', parse_dates=['Date'])
    df[ticker] = tmddf['Close']

df.head()
# Out:
#                  AAPL         AMZN         GM         JNJ        XOM
# Date
# 2020-03-17  63.215000  1807.839966  20.320000  136.589996  36.810001
# 2020-03-18  61.667500  1830.000000  16.799999  134.960007  33.119999
# 2020-03-19  61.195000  1880.930054  17.709999  127.050003  34.430000
# 2020-03-20  57.310001  1846.089966  18.139999  119.889999  32.740002
# 2020-03-23  56.092499  1902.829956  17.600000  111.139999  31.450001

# %%
len(df)  # Rows in the dataset
# Out:
# 253

# %%
ax = df[[t for t in TICKERS if t != 'AMZN']].plot(figsize=FIGSIZE)
df[['AMZN']].plot(secondary_y=True, ax=ax)
plt.savefig('figs/data',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Statistical Tests and Transformations

# %%
def adf_test(series,title=''):
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(), autolag='AIC')  # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
for ticker in TICKERS:
    adf_test(df[ticker], title=ticker)
    print()
# Out:
# Augmented Dickey-Fuller Test: AAPL
# ADF test statistic       -1.701756
# p-value                   0.430208
# # lags used               0.000000
# # observations          252.000000
# critical value (1%)      -3.456569
# critical value (5%)      -2.873079
# critical value (10%)     -2.572919
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
# Augmented Dickey-Fuller Test: AMZN
# ADF test statistic       -2.836689
# p-value                   0.053221
# # lags used               3.000000
# # observations          249.000000
# critical value (1%)      -3.456888
# critical value (5%)      -2.873219
# critical value (10%)     -2.572994
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
# Augmented Dickey-Fuller Test: GM
# ADF test statistic        0.325325
# p-value                   0.978477
# # lags used               0.000000
# # observations          252.000000
# critical value (1%)      -3.456569
# critical value (5%)      -2.873079
# critical value (10%)     -2.572919
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
# Augmented Dickey-Fuller Test: JNJ
# ADF test statistic       -2.013894
# p-value                   0.280515
# # lags used               0.000000
# # observations          252.000000
# critical value (1%)      -3.456569
# critical value (5%)      -2.873079
# critical value (10%)     -2.572919
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
# Augmented Dickey-Fuller Test: XOM
# ADF test statistic       -0.704828
# p-value                   0.845495
# # lags used               0.000000
# # observations          252.000000
# critical value (1%)      -3.456569
# critical value (5%)      -2.873079
# critical value (10%)     -2.572919
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %% [markdown]
# As we can see, all the series are non-stationary, so we will take the first difference (and also apply a log transformation because these are stock prices):

# %%
df1d = pd.DataFrame(logret(df))

for ticker in TICKERS:
    adf_test(df1d[ticker], title=ticker)
    print()
# Out:
# Augmented Dickey-Fuller Test: AAPL
# ADF test statistic     -1.767079e+01
# p-value                 3.645620e-30
# # lags used             0.000000e+00
# # observations          2.510000e+02
# critical value (1%)    -3.456674e+00
# critical value (5%)    -2.873125e+00
# critical value (10%)   -2.572944e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
# Augmented Dickey-Fuller Test: AMZN
# ADF test statistic     -1.049537e+01
# p-value                 1.119123e-18
# # lags used             2.000000e+00
# # observations          2.490000e+02
# critical value (1%)    -3.456888e+00
# critical value (5%)    -2.873219e+00
# critical value (10%)   -2.572994e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
# Augmented Dickey-Fuller Test: GM
# ADF test statistic     -1.646259e+01
# p-value                 2.322668e-29
# # lags used             0.000000e+00
# # observations          2.510000e+02
# critical value (1%)    -3.456674e+00
# critical value (5%)    -2.873125e+00
# critical value (10%)   -2.572944e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
# Augmented Dickey-Fuller Test: JNJ
# ADF test statistic     -1.665926e+01
# p-value                 1.579342e-29
# # lags used             0.000000e+00
# # observations          2.510000e+02
# critical value (1%)    -3.456674e+00
# critical value (5%)    -2.873125e+00
# critical value (10%)   -2.572944e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
# Augmented Dickey-Fuller Test: XOM
# ADF test statistic     -1.085111e+01
# p-value                 1.527977e-19
# # lags used             2.000000e+00
# # observations          2.490000e+02
# critical value (1%)    -3.456888e+00
# critical value (5%)    -2.873219e+00
# critical value (10%)   -2.572994e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# According to the Augmented Dickey-Fuller Test, all the series are now stationary, and we can therefore proceed with the transformed data to further analysis.

# %%
OBS = 7  # The "length" of our predictions will be 7 days.

# %% [markdown]
# We split our data to training and testing datasets:

# %%
train = df[:-OBS]
train1d = df1d[:-OBS]
test = df[-OBS:]

# %% [markdown]
# ## Vector Autoregression

# %% [markdown]
# First, we perform Vector Autoregressions of lag orders from 1 to 10, in order to select the optimal.
#
# The optimal is the one that minimizes the Akaike Information Criterion (AIC).
#
# For completeness, we also show the BIC (Bayesian Information Criterion, also known as Schwarz Information Criterion).

# %%
tmpdf = pd.DataFrame(columns=['Order', 'AIC', 'BIC'])

for i in range(1, 10):
    model = VAR(train1d)
    results = model.fit(i)
    tmpdf.loc[i] = pd.Series({'Order': i, 'AIC': results.aic, 'BIC': results.bic})

tmpdf
# Out:
#    Order        AIC        BIC
# 1    1.0 -38.487361 -38.057381
# 2    2.0 -38.589557 -37.798946
# 3    3.0 -38.558152 -37.404785
# 4    4.0 -38.580178 -37.061906
# 5    5.0 -38.690278 -36.804932
# 6    6.0 -38.679816 -36.425206
# 7    7.0 -38.605015 -35.978928
# 8    8.0 -38.571376 -35.571578
# 9    9.0 -38.569295 -35.193527

# %%
lag_order = tmpdf.idxmin()['AIC']

# %% [markdown]
# We see that the AIC is minimized for the VAR(5) model, so this will be the order of choice for the VAR model.

# %% [markdown]
# We proceed to train the model:

# %%
model = VAR(train1d)
model_fitted = model.fit(lag_order)
model_fitted.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 07, Apr, 2021
# Time:                     01:04:08
# --------------------------------------------------------------------
# No. of Equations:         5.00000    BIC:                   -36.8049
# Nobs:                     240.000    HQIC:                  -37.9306
# Log likelihood:           3070.11    FPE:                1.58081e-17
# AIC:                     -38.6903    Det(Omega_mle):     9.45208e-18
# --------------------------------------------------------------------
# Results for equation AAPL
# ==========================================================================
#              coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------
# const           0.002493         0.001676            1.487           0.137
# L1.AAPL         0.000371         0.099633            0.004           0.997
# L1.AMZN        -0.051456         0.105345           -0.488           0.625
# L1.GM           0.034286         0.061731            0.555           0.579
# L1.JNJ         -0.114310         0.134282           -0.851           0.395
# L1.XOM         -0.111897         0.070782           -1.581           0.114
# L2.AAPL        -0.021541         0.098626           -0.218           0.827
# L2.AMZN         0.017452         0.103235            0.169           0.866
# L2.GM           0.037609         0.062498            0.602           0.547
# L2.JNJ          0.185343         0.131712            1.407           0.159
# L2.XOM          0.016441         0.071528            0.230           0.818
# L3.AAPL        -0.018270         0.097754           -0.187           0.852
# L3.AMZN        -0.050848         0.101322           -0.502           0.616
# L3.GM          -0.018204         0.062920           -0.289           0.772
# L3.JNJ         -0.037493         0.130289           -0.288           0.774
# L3.XOM          0.034908         0.071790            0.486           0.627
# L4.AAPL        -0.060755         0.097394           -0.624           0.533
# L4.AMZN         0.107669         0.100755            1.069           0.285
# L4.GM           0.072857         0.062375            1.168           0.243
# L4.JNJ         -0.179621         0.123264           -1.457           0.145
# L4.XOM         -0.012237         0.072118           -0.170           0.865
# L5.AAPL        -0.062193         0.097836           -0.636           0.525
# L5.AMZN         0.087453         0.100664            0.869           0.385
# L5.GM          -0.020142         0.059506           -0.338           0.735
# L5.JNJ          0.147112         0.122612            1.200           0.230
# L5.XOM          0.052520         0.071344            0.736           0.462
# ==========================================================================
#
# Results for equation AMZN
# ==========================================================================
#              coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------
# const           0.001434         0.001525            0.940           0.347
# L1.AAPL         0.039179         0.090670            0.432           0.666
# L1.AMZN        -0.042130         0.095868           -0.439           0.660
# L1.GM           0.091185         0.056178            1.623           0.105
# L1.JNJ         -0.155602         0.122202           -1.273           0.203
# L1.XOM         -0.084145         0.064415           -1.306           0.191
# L2.AAPL        -0.100021         0.089753           -1.114           0.265
# L2.AMZN         0.011437         0.093948            0.122           0.903
# L2.GM           0.004302         0.056876            0.076           0.940
# L2.JNJ          0.325286         0.119863            2.714           0.007
# L2.XOM          0.007486         0.065093            0.115           0.908
# L3.AAPL         0.027110         0.088960            0.305           0.761
# L3.AMZN        -0.159345         0.092207           -1.728           0.084
# L3.GM          -0.009129         0.057260           -0.159           0.873
# L3.JNJ          0.037705         0.118569            0.318           0.750
# L3.XOM         -0.008553         0.065332           -0.131           0.896
# L4.AAPL         0.025895         0.088632            0.292           0.770
# L4.AMZN         0.014896         0.091691            0.162           0.871
# L4.GM           0.055609         0.056764            0.980           0.327
# L4.JNJ         -0.060987         0.112175           -0.544           0.587
# L4.XOM         -0.008353         0.065630           -0.127           0.899
# L5.AAPL        -0.086791         0.089035           -0.975           0.330
# L5.AMZN         0.055926         0.091609            0.610           0.542
# L5.GM           0.075405         0.054153            1.392           0.164
# L5.JNJ          0.118545         0.111581            1.062           0.288
# L5.XOM         -0.053479         0.064926           -0.824           0.410
# ==========================================================================
#
# Results for equation GM
# ==========================================================================
#              coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------
# const           0.005192         0.002181            2.381           0.017
# L1.AAPL         0.111202         0.129623            0.858           0.391
# L1.AMZN        -0.221328         0.137054           -1.615           0.106
# L1.GM           0.107206         0.080313            1.335           0.182
# L1.JNJ         -0.322792         0.174702           -1.848           0.065
# L1.XOM          0.003281         0.092088            0.036           0.972
# L2.AAPL        -0.026393         0.128313           -0.206           0.837
# L2.AMZN         0.016477         0.134310            0.123           0.902
# L2.GM           0.082504         0.081311            1.015           0.310
# L2.JNJ          0.072653         0.171358            0.424           0.672
# L2.XOM         -0.110221         0.093058           -1.184           0.236
# L3.AAPL        -0.066393         0.127179           -0.522           0.602
# L3.AMZN         0.025381         0.131820            0.193           0.847
# L3.GM          -0.098974         0.081860           -1.209           0.227
# L3.JNJ          0.275240         0.169507            1.624           0.104
# L3.XOM         -0.066668         0.093400           -0.714           0.475
# L4.AAPL        -0.097271         0.126710           -0.768           0.443
# L4.AMZN         0.068212         0.131083            0.520           0.603
# L4.GM          -0.093462         0.081151           -1.152           0.249
# L4.JNJ         -0.145356         0.160367           -0.906           0.365
# L4.XOM          0.086066         0.093826            0.917           0.359
# L5.AAPL         0.186836         0.127286            1.468           0.142
# L5.AMZN        -0.166179         0.130965           -1.269           0.204
# L5.GM          -0.179303         0.077418           -2.316           0.021
# L5.JNJ         -0.274812         0.159519           -1.723           0.085
# L5.XOM          0.228474         0.092819            2.462           0.014
# ==========================================================================
#
# Results for equation JNJ
# ==========================================================================
#              coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------
# const           0.000550         0.000947            0.581           0.561
# L1.AAPL         0.011202         0.056266            0.199           0.842
# L1.AMZN        -0.042927         0.059491           -0.722           0.471
# L1.GM          -0.033208         0.034861           -0.953           0.341
# L1.JNJ         -0.088989         0.075833           -1.173           0.241
# L1.XOM          0.060543         0.039973            1.515           0.130
# L2.AAPL         0.040026         0.055697            0.719           0.472
# L2.AMZN         0.062426         0.058300            1.071           0.284
# L2.GM           0.022646         0.035294            0.642           0.521
# L2.JNJ          0.119127         0.074382            1.602           0.109
# L2.XOM         -0.026862         0.040394           -0.665           0.506
# L3.AAPL        -0.063444         0.055204           -1.149           0.250
# L3.AMZN         0.058330         0.057219            1.019           0.308
# L3.GM          -0.025261         0.035533           -0.711           0.477
# L3.JNJ          0.008268         0.073578            0.112           0.911
# L3.XOM          0.003257         0.040542            0.080           0.936
# L4.AAPL         0.074652         0.055001            1.357           0.175
# L4.AMZN        -0.062865         0.056899           -1.105           0.269
# L4.GM           0.073059         0.035225            2.074           0.038
# L4.JNJ         -0.080124         0.069611           -1.151           0.250
# L4.XOM         -0.037647         0.040727           -0.924           0.355
# L5.AAPL        -0.060967         0.055251           -1.103           0.270
# L5.AMZN         0.135836         0.056848            2.389           0.017
# L5.GM           0.019534         0.033605            0.581           0.561
# L5.JNJ         -0.030795         0.069242           -0.445           0.657
# L5.XOM          0.023133         0.040290            0.574           0.566
# ==========================================================================
#
# Results for equation XOM
# ==========================================================================
#              coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------
# const           0.003822         0.001942            1.968           0.049
# L1.AAPL        -0.074433         0.115451           -0.645           0.519
# L1.AMZN        -0.186635         0.122069           -1.529           0.126
# L1.GM           0.033724         0.071532            0.471           0.637
# L1.JNJ         -0.114842         0.155601           -0.738           0.460
# L1.XOM         -0.034902         0.082020           -0.426           0.670
# L2.AAPL         0.079479         0.114284            0.695           0.487
# L2.AMZN        -0.069988         0.119625           -0.585           0.559
# L2.GM           0.096081         0.072421            1.327           0.185
# L2.JNJ          0.030941         0.152623            0.203           0.839
# L2.XOM         -0.102920         0.082884           -1.242           0.214
# L3.AAPL        -0.158440         0.113274           -1.399           0.162
# L3.AMZN         0.132030         0.117408            1.125           0.261
# L3.GM          -0.036721         0.072910           -0.504           0.615
# L3.JNJ          0.304484         0.150974            2.017           0.044
# L3.XOM         -0.130708         0.083188           -1.571           0.116
# L4.AAPL        -0.118946         0.112856           -1.054           0.292
# L4.AMZN         0.129298         0.116751            1.107           0.268
# L4.GM          -0.037771         0.072278           -0.523           0.601
# L4.JNJ         -0.205615         0.142834           -1.440           0.150
# L4.XOM          0.068524         0.083567            0.820           0.412
# L5.AAPL        -0.019377         0.113369           -0.171           0.864
# L5.AMZN        -0.051097         0.116646           -0.438           0.661
# L5.GM          -0.222069         0.068953           -3.221           0.001
# L5.JNJ          0.100109         0.142078            0.705           0.481
# L5.XOM          0.238802         0.082671            2.889           0.004
# ==========================================================================
#
# Correlation matrix of residuals
#             AAPL      AMZN        GM       JNJ       XOM
# AAPL    1.000000  0.703856  0.171370  0.370146  0.142786
# AMZN    0.703856  1.000000  0.061412  0.285246  0.045988
# GM      0.171370  0.061412  1.000000  0.318190  0.544009
# JNJ     0.370146  0.285246  0.318190  1.000000  0.375040
# XOM     0.142786  0.045988  0.544009  0.375040  1.000000

# %% [markdown]
# Predictions:

# %%
preds_var_1d = pd.DataFrame(
    model_fitted.forecast(y=train1d.values[-lag_order:], steps=OBS),
    columns=TICKERS,
    index=test.index.copy())

# %% [markdown]
# Evaluation of the forecast:
#   - Visualization of the forecast
#   - Root Mean Square Error, Mean Absolute Error, Mean Square Error used as evaluation metrics

# %%
preds_var = revlogret(preds_var_1d, df.iloc[-OBS-1].values)
preds_var  # VAR Predictions
# Out:
#                   AAPL         AMZN         GM         JNJ        XOM
# Date
# 2021-03-09  117.537530  2978.271659  54.824307  157.686122  60.790878
# 2021-03-10  117.952497  2985.612046  56.276787  156.776397  61.818153
# 2021-03-11  118.118905  2987.650181  57.663921  157.476751  62.992500
# 2021-03-12  118.739688  2988.838073  57.872513  157.540823  63.424863
# 2021-03-15  119.420462  3011.755608  57.207275  157.734188  63.138570
# 2021-03-16  120.075668  3015.835803  57.161380  158.082170  63.177330
# 2021-03-17  120.325251  3022.327709  57.325100  158.514231  63.006188

# %%
test  # Original Test Data
# Out:
#                   AAPL         AMZN         GM         JNJ        XOM
# Date
# 2021-03-09  121.089996  3062.850098  54.650002  157.699997  59.930000
# 2021-03-10  119.980003  3057.639893  56.830002  159.149994  61.770000
# 2021-03-11  121.959999  3113.590088  56.330002  159.139999  61.310001
# 2021-03-12  121.029999  3089.489990  59.259998  159.600006  61.970001
# 2021-03-15  123.989998  3081.679932  57.939999  160.419998  60.389999
# 2021-03-16  125.570000  3091.860107  57.119999  161.369995  59.110001
# 2021-03-17  124.514999  3141.010010  59.480000  160.884995  59.255001

# %%
fig, axs = plt.subplots(5)

for ax, ticker in zip(axs, TICKERS):
    test[ticker].plot(figsize=(15, 20), title=ticker, legend=True, ax=ax)
    preds_var[ticker].plot(legend=True, ax=ax, label=ticker + ' Prediction')

plt.savefig('figs/var')
plt.show()

# %%
evals(test, preds_var, TICKERS)
# Out:
# Stock              RMSE               MAE                MSE
# ------------------ ------------------ ------------------ ------------------
# AAPL               3.8794819820419333 3.7092848332803317 15.050380448988006
# AMZN               94.93440299943956  92.54700559922776  9012.540872859998
# GM                 1.147859643474506  0.9111326642515252 1.3175817611174203
# JNJ                2.2767354919336364 2.0649001780869054 5.1835245002302965
# XOM                2.503142919806605  2.0876400046291357 6.265724476977937

# %% [markdown]
# ## Auto Regressive Integrated Moving Average

# %% [markdown]
# Now we move on to ARIMA models.
#
# First, we select the optimal model according to the Akaike Information Criterion again:

# %%
order = {}

cols = [
    ['Stock', 'Optimal ARMA Order']
]

for ticker in TICKERS:
    recomm = arma_order_select_ic(train1d[ticker], ic='aic')['aic_min_order']
    order[ticker] = recomm
    cols.append([ticker, str(recomm)])

print_cols(cols)
# Out:
# Stock              Optimal ARMA Order
# AAPL               (1, 0)
# AMZN               (0, 0)
# GM                 (3, 2)
# JNJ                (4, 2)
# XOM                (2, 2)

# %%
models = {}

for ticker in TICKERS:
    models[ticker] = ARMA(train1d[ticker], order=order[ticker]).fit()
    print(models[ticker].summary())
    print()
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                   AAPL   No. Observations:                  245
# Model:                     ARMA(1, 0)   Log Likelihood                 559.460
# Method:                       css-mle   S.D. of innovations              0.025
# Date:                Wed, 07 Apr 2021   AIC                          -1112.921
# Time:                        01:04:24   BIC                          -1102.417
# Sample:                             0   HQIC                         -1108.691
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0025      0.001      1.751      0.080      -0.000       0.005
# ar.L1.AAPL    -0.0968      0.064     -1.511      0.131      -0.222       0.029
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -10.3289           +0.0000j           10.3289            0.5000
# -----------------------------------------------------------------------------
#
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                   AMZN   No. Observations:                  245
# Model:                     ARMA(0, 0)   Log Likelihood                 589.656
# Method:                           css   S.D. of innovations              0.022
# Date:                Wed, 07 Apr 2021   AIC                          -1175.311
# Time:                        01:04:24   BIC                          -1168.309
# Sample:                             0   HQIC                         -1172.491
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.001      1.437      0.151      -0.001       0.005
# ==============================================================================
#
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                     GM   No. Observations:                  245
# Model:                     ARMA(3, 2)   Log Likelihood                 478.730
# Method:                       css-mle   S.D. of innovations              0.034
# Date:                Wed, 07 Apr 2021   AIC                           -943.459
# Time:                        01:04:24   BIC                           -918.950
# Sample:                             0   HQIC                          -933.589
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.002      2.190      0.029       0.000       0.008
# ar.L1.GM       1.4983      0.078     19.281      0.000       1.346       1.651
# ar.L2.GM      -0.8339      0.121     -6.870      0.000      -1.072      -0.596
# ar.L3.GM      -0.0932      0.073     -1.283      0.200      -0.236       0.049
# ma.L1.GM      -1.5229      0.046    -33.454      0.000      -1.612      -1.434
# ma.L2.GM       0.8906      0.055     16.105      0.000       0.782       0.999
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.8089           -0.6010j            1.0077           -0.1017
# AR.2            0.8089           +0.6010j            1.0077            0.1017
# AR.3          -10.5628           -0.0000j           10.5628           -0.5000
# MA.1            0.8550           -0.6259j            1.0597           -0.1006
# MA.2            0.8550           +0.6259j            1.0597            0.1006
# -----------------------------------------------------------------------------
#
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                    JNJ   No. Observations:                  245
# Model:                     ARMA(4, 2)   Log Likelihood                 675.832
# Method:                       css-mle   S.D. of innovations              0.015
# Date:                Wed, 07 Apr 2021   AIC                          -1335.664
# Time:                        01:04:25   BIC                          -1307.654
# Sample:                             0   HQIC                         -1324.384
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.001      0.600      0.549      -0.001       0.003
# ar.L1.JNJ     -1.4122      0.175     -8.069      0.000      -1.755      -1.069
# ar.L2.JNJ     -0.3592      0.204     -1.757      0.079      -0.760       0.042
# ar.L3.JNJ      0.1025      0.129      0.796      0.426      -0.150       0.355
# ar.L4.JNJ     -0.1137      0.098     -1.163      0.245      -0.305       0.078
# ma.L1.JNJ      1.4437      0.168      8.592      0.000       1.114       1.773
# ma.L2.JNJ      0.5661      0.174      3.250      0.001       0.225       0.907
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.9999           -0.3496j            1.0593           -0.4465
# AR.2           -0.9999           +0.3496j            1.0593            0.4465
# AR.3            1.4507           -2.3948j            2.8000           -0.1633
# AR.4            1.4507           +2.3948j            2.8000            0.1633
# MA.1           -1.2751           -0.3748j            1.3291           -0.4545
# MA.2           -1.2751           +0.3748j            1.3291            0.4545
# -----------------------------------------------------------------------------
#
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                    XOM   No. Observations:                  245
# Model:                     ARMA(2, 2)   Log Likelihood                 510.109
# Method:                       css-mle   S.D. of innovations              0.030
# Date:                Wed, 07 Apr 2021   AIC                          -1008.218
# Time:                        01:04:25   BIC                           -987.210
# Sample:                             0   HQIC                          -999.758
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.002      1.222      0.222      -0.001       0.005
# ar.L1.XOM      1.5755      0.043     36.419      0.000       1.491       1.660
# ar.L2.XOM     -0.9452      0.047    -20.288      0.000      -1.037      -0.854
# ma.L1.XOM     -1.6300      0.033    -48.862      0.000      -1.695      -1.565
# ma.L2.XOM      0.9609      0.034     27.895      0.000       0.893       1.028
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.8334           -0.6029j            1.0286           -0.0997
# AR.2            0.8334           +0.6029j            1.0286            0.0997
# MA.1            0.8482           -0.5669j            1.0202           -0.0938
# MA.2            0.8482           +0.5669j            1.0202            0.0938
# -----------------------------------------------------------------------------

# %%
preds_arima_1d = pd.DataFrame(index=test.index.copy())

for ticker in TICKERS:
    predictions = models[ticker].predict(start=len(train1d), end=len(train1d) + len(test) - 1)
    predictions.index = test.index.copy()
    preds_arima_1d[ticker] = predictions

preds_arima = revlogret(preds_arima_1d, train.iloc[-1].values)
preds_arima  # ARIMA Predictions
# Out:
#                   AAPL         AMZN         GM         JNJ        XOM
# Date
# 2021-03-09  117.163465  2957.863780  55.018338  158.167578  60.562701
# 2021-03-10  117.409049  2963.789457  55.075359  158.176011  60.202584
# 2021-03-11  117.709694  2969.727005  55.109667  157.949310  59.972206
# 2021-03-12  118.005812  2975.676448  55.207051  158.475957  59.994687
# 2021-03-15  118.303190  2981.637810  55.416723  158.006520  60.294949
# 2021-03-16  118.601267  2987.611115  55.745246  158.736182  60.796792
# 2021-03-17  118.900100  2993.596386  56.153219  158.233789  61.353627

# %%
test
# Out:
#                   AAPL         AMZN         GM         JNJ        XOM
# Date
# 2021-03-09  121.089996  3062.850098  54.650002  157.699997  59.930000
# 2021-03-10  119.980003  3057.639893  56.830002  159.149994  61.770000
# 2021-03-11  121.959999  3113.590088  56.330002  159.139999  61.310001
# 2021-03-12  121.029999  3089.489990  59.259998  159.600006  61.970001
# 2021-03-15  123.989998  3081.679932  57.939999  160.419998  60.389999
# 2021-03-16  125.570000  3091.860107  57.119999  161.369995  59.110001
# 2021-03-17  124.514999  3141.010010  59.480000  160.884995  59.255001

# %%
fig, axs = plt.subplots(5)

for ax, ticker in zip(axs, TICKERS):
    test[ticker].plot(figsize=(15, 20), title=ticker, legend=True, ax=ax, label=ticker + ' Actual')
    preds_arima[ticker].plot(legend=True, ax=ax, label=ticker + 'ARIMA Prediction')
    preds_var[ticker].plot(legend=True, ax=ax, label=ticker + ' VAR Prediction')

plt.savefig('figs/arima')
plt.show()

# %%
evals(test, preds_arima, TICKERS)
# Out:
# Stock              RMSE               MAE                MSE
# ------------------ ------------------ ------------------ ------------------
# AAPL               4.805775808501692  4.577488114465644  23.095481121580093
# AMZN               117.16118023980027 115.45973085378311 13726.742155182967
# GM                 2.403996024170232  2.0887244270377314 5.779196884226281
# JNJ                1.8376709731470786 1.6363999230740254 3.377034605547331
# XOM                1.5027209748725667 1.341956100072425  2.2581703283219574

# %% [markdown]
# ## Recurrent Neural Network - Long Short-Term Memory Architecture

# %% [markdown]
# First we will need to apply some transformations to make the network more robust, which we will later revert to perform forecasting, like we did previously:

# %%
def train_and_predict(series, ticker):
    train = pd.DataFrame(series.iloc[:-OBS])
    test = pd.DataFrame(series.iloc[-OBS:])
    
    scaler = MinMaxScaler()
    scaler.fit(train)
    train_scaled = scaler.transform(train)
    test_scaled = scaler.transform(test)
    
    n_input = OBS
    n_features = 1

    generator = TimeseriesGenerator(train_scaled,
                                    train_scaled,
                                    length=n_input,
                                    batch_size=1)

    model = Sequential()
    model.add(LSTM(160, activation='relu', input_shape=(n_input, n_features)))
    model.add(Dense(n_features))
    model.compile(optimizer='adam', loss='mse')

    model.fit_generator(generator, epochs=8)

    test_predictions = []

    first_eval_batch = train_scaled[-n_input:]
    current_batch = first_eval_batch.reshape((1, n_input, n_features))

    for i in range(len(test)):

        # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
        current_pred = model.predict(current_batch)[0]

        # store prediction
        test_predictions.append(current_pred)

        # update batch to now include prediction and drop first value
        current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis=1)

    true_predictions = scaler.inverse_transform(test_predictions)
    return pd.DataFrame(true_predictions, columns=[ticker], index=test.index.copy())

# %%
preds_lstm = pd.DataFrame(index=test.index.copy())

for ticker in TICKERS:
    preds_lstm[ticker] = train_and_predict(df[ticker], ticker)
# Out:
# Epoch 1/8
# 239/239 [==============================] - 1s 2ms/step - loss: 0.0710
# Epoch 2/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 3/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 4/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 5/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 6/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 7/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 8/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 1/8
# 239/239 [==============================] - 1s 2ms/step - loss: 0.0821
# Epoch 2/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 3/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 4/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 5/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 6/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 7/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 8/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 1/8
# 239/239 [==============================] - 1s 2ms/step - loss: 0.0529
# Epoch 2/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 3/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 4/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 5/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 6/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 7/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 8/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 1/8
# 239/239 [==============================] - 1s 2ms/step - loss: 0.0782
# Epoch 2/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 3/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 4/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 5/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 6/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 7/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 8/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 1/8
# 239/239 [==============================] - 1s 2ms/step - loss: 0.0500
# Epoch 2/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 3/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 4/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 5/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 6/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 7/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 8/8
# 239/239 [==============================] - 0s 2ms/step - loss: 0.0037

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)), loss_per_epoch)

# %%
preds_lstm
# Out:
#                 AAPL      AMZN        GM       JNJ       XOM
# Date
# 2021-03-09  0.737769  0.741571  0.930026  0.774119  0.971075
# 2021-03-10  0.736880  0.751562  0.936198  0.773491  0.974907
# 2021-03-11  0.730984  0.759775  0.939052  0.772335  0.977456
# 2021-03-12  0.728779  0.768344  0.942134  0.771270  0.985168
# 2021-03-15  0.726147  0.778766  0.947380  0.772618  0.992388
# 2021-03-16  0.724648  0.790075  0.954343  0.777293  0.999337
# 2021-03-17  0.722412  0.801336  0.959136  0.779256  1.006821

# %% [markdown]
# Evaluate on Test Data

# %%
fig, axs = plt.subplots(5)

for ax, ticker in zip(axs, TICKERS):
    test[ticker].plot(figsize=(15, 20), title=ticker, legend=True, ax=ax, label=ticker + ' Actual')
    preds_arima[ticker].plot(legend=True, ax=ax, label=ticker + 'ARIMA Prediction')
    preds_var[ticker].plot(legend=True, ax=ax, label=ticker + ' VAR Prediction')
    preds_lstm[ticker].plot(legend=True, ax=ax, label=ticker + ' LSTM')

plt.savefig('figs/lstm')
plt.show()

# %%
evals(test, preds_lstm, TICKERS)
# Out:
# Stock              RMSE               MAE                MSE
# ------------------ ------------------ ------------------ ------------------
# AAPL               2.435933280810117  1.8628372747320239 5.933770948558339
# AMZN               25.493285128416193 21.95084551684918  649.9075866387262
# GM                 2.0428102570556903 1.6928796974797078 4.173073746331935
# JNJ                5.269393405147601  4.996310691381552  27.766506858213027
# XOM                4.681681913916904  3.513923441759829  21.91814554309665
